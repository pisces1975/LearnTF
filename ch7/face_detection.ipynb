# %% [markdown]
# # 使用 OpenCV 进行人脸检测

# %%
#The line below is necesary to show Matplotlib's plots inside a Jupyter Notebook
# %matplotlib inline

import cv2
from matplotlib import pyplot as plt
import os
os.chdir(r"C:\Users\NstcUser\py37\repo\LearnTensorflow\ch7")

imagePath = './face_detection/test_face_detection.jpg'
# Haar级联分类器文件的路径。Haar级联分类器是一种用于对象检测的方法，这里使用的是用于人脸检测的分类器文件
cascPath = "./face_detection/haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# Read the image
image = cv2.imread(imagePath)
# 读取图像并将其转换为灰度图像：cv2.imread(imagePath)读取图像，cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)将彩色图像转换为灰度图像
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image, 返回一个包含人脸坐标的列表
faces = faceCascade.detectMultiScale(
    gray, # 灰度图像
    scaleFactor=1.1, #用于图像尺度调整的比例因子
    minNeighbors=5, # 一个人脸被检测到的最小邻居数
    minSize=(30, 30) # 人脸的最小尺寸
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.title("Faces found")
plt.axis("off") # 关闭坐标轴
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Found 4 faces!

# %% [markdown]
# # 使用 face_recognition 库进行人脸检测

# %%
import face_recognition

imagePath = './face_detection/test_face_detection.jpg'

# Load the image with face_recognition
image = face_recognition.load_image_file(imagePath)
# Detect faces in the image
face_locations = face_recognition.face_locations(image)

print("Found {0} faces!".format(len(face_locations)))


# Read the image with openCV
image = cv2.imread(imagePath)

# Draw a rectangle around the faces
for (top, right, bottom, left) in face_locations:
    cv2.rectangle(image, (left, top), (right, bottom), (0, 255, 0), 2)


plt.title("Faces found")
plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Found 5 faces!
